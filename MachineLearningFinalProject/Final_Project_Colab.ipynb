# %% [markdown]
# #Final Project: Climate Change Prediction

# %% [markdown]
# #Importing Packages

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #Reading Data
#
# #### Data Dictionary
# Coal_Cons: 10 year average Coal consumption in ExaJoules growth rate %
#
# Coal_Prod: 10 year average Coal Production in ExaJoules growth rate %
#
# Nuke_Cons: 10 year average Nuclear consumption in Terawatt-Hours growth rate %
#
# Nuke_Prod: 10 year average Nuclear production in Terawatt-Hours growth rate %
#
# Natgas_Cons:  10 year average Natgas consumption in ExaJoules growth rate %
#
# Natgas_Prod:10 year average Natgas production in ExaJoules growth rate %
#
# Hydro_Cons: 10 year average Hydro consumption in Terawatt-Hours growth rate %
#
# Hydro_Prod: 10 year average Hydro production in Terawatt-Hours growth rate %
#
# Oil_Cons: 10 year average Oil consumption in 1000s daily barrels growth rate %
#
# Oil_Prod: 10 year average Oil production in 1000s daily barrels growth rate %
#
# Sol_Cons: 10 year average Solar consumption in Terawatt-Hours growth rate %
#
# Sol_Prod: 10 year average Solar Production in Terawatt-Hours growth rate %
#
# Wind_Cons: 10 year average Wind consumption in Terawatt-Hours growth rate %
#
# Wind_Prod: 10 year average Wind Production in Terawatt-Hours growth rate %
#
# Co2: 10 year average millions of tons of Co2 Emissions growth rate %
#
# GDP: 10 Year average gdp growth rate

# %%
coal_cons = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Coal_Consumption_EJ.csv')
coal_prod = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Coal_Production_EJ.csv')

nuke_cons = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Nuclear_Consumption_Exa.csv', encoding = 'unicode_escape')
nuke_prod = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Nuclear_Production_Exa.csv', encoding = 'unicode_escape')

natgas_cons = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Natural_Gas_Consumption_Exa.csv',encoding = 'unicode_escape')
natgas_prod = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Natural_Gas__Production_Exa.csv',encoding = 'unicode_escape')

hydro_cons = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Hydro_Consumption_Exa.csv')
hydro_prod = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Hydro_Production_Exa.csv')

oil_cons = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Oil_Consumption_Barrels_Daily.csv')
oil_prod = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Oil_Prod_barrels_daily.csv')

sol_cons = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Solar_Consumption_Exa.csv', encoding = 'unicode_escape')
sol_prod = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Solar_Production_Exa.csv', encoding = 'unicode_escape')

wind_cons = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Wind_Consumption_Exa.csv', encoding = 'unicode_escape')
wind_prod = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Wind_Production_Exa.csv', encoding = 'unicode_escape')

co2 = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/CO2_Emissions.csv')

gdp = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/GDP_Growth_Rate.csv')

pop = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Population_Growth_Rate.csv')

warming = pd.read_excel('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Warming_data%20(3).xlsx')

elevation = pd.read_excel('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Elevation_by_country%20(1).xlsx')

# %%
# Manually Reading in the Three Datasets
new_data = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/countries_of_the_world.csv')
emissions = pd.read_csv('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/PERCAP.csv')

# %%
coal_prod.rename(columns={'Exajoules':'Country'}, inplace=True)
coal_prod.set_index('Country', inplace=True)
coal_prod = coal_prod['2008-18']

coal_cons.rename(columns={'Exajoules':'Country'}, inplace=True)
coal_cons.set_index('Country', inplace=True)
coal_cons = coal_cons['2008-18']

# %%
nuke_prod.rename(columns={'Terawatt-hours':'Country'}, inplace=True)
nuke_prod.set_index('Country', inplace=True)
nuke_prod = nuke_prod['2008-18']

nuke_cons.rename(columns={'Exajoules (input-equivalent)':'Country'}, inplace=True)
nuke_cons.set_index('Country', inplace=True)
nuke_cons = nuke_cons['2008-18']

# %%
natgas_cons.rename(columns={'Exajoules':'Country'}, inplace=True)
natgas_cons.set_index('Country', inplace=True)
natgas_cons = natgas_cons['2008-18']

natgas_prod.rename(columns={'Exajoules':'Country'}, inplace=True)
natgas_prod.set_index('Country', inplace=True)
natgas_prod = natgas_prod['2008-18']

# %%
hydro_cons.rename(columns={'Exajoules':'Country'}, inplace=True)
hydro_cons.set_index('Country', inplace=True)
hydro_cons = hydro_cons['2008-18']

hydro_prod.rename(columns={'Terawatt-hours':'Country'}, inplace=True)
hydro_prod.set_index('Country', inplace=True)
hydro_prod = hydro_prod['2008-18']

# %%
oil_cons.rename(columns={'Thousand barrels daily':'Country'}, inplace=True)
oil_cons.set_index('Country', inplace=True)
oil_cons = oil_cons['2008-18']

oil_prod.rename(columns={'Thousand barrels daily':'Country'}, inplace=True)
oil_prod.set_index('Country', inplace=True)
oil_prod = oil_prod['2008-18']

# %%
sol_cons.rename(columns={'Exajoules (input-equivalent)':'Country'}, inplace=True)
sol_cons.set_index('Country', inplace=True)
sol_cons = sol_cons['2008-18']

sol_prod.rename(columns={'Terawatt-hours':'Country'}, inplace=True)
sol_prod.set_index('Country', inplace=True)
sol_prod = sol_prod['2008-18']

# %%
wind_cons.rename(columns={'Exajoules (input-equivalent)':'Country'}, inplace=True)
wind_cons.set_index('Country', inplace=True)
wind_cons = wind_cons['2008-18']

wind_prod.rename(columns={'Terawatt-hours':'Country'}, inplace=True)
wind_prod.set_index('Country', inplace=True)
wind_prod = wind_prod['2008-18']

# %%
co2.rename(columns={'Million tonnes of carbon dioxide':'Country'}, inplace=True)
co2.set_index('Country', inplace=True)
co2 = co2['2008-18']

# %%
gdp.rename(columns={'Country Name':'Country'}, inplace=True)
gdp.set_index('Country', inplace=True)
gdp['gdp'] = gdp.mean(axis=1)
gdp = gdp['gdp']

# %%
pop.rename(columns={'Country Name':'Country'}, inplace=True)
pop.set_index('Country', inplace=True)
pop['pop'] = pop.mean(axis=1)
pop = pop['pop']

# %%
elevation['Country'] = elevation['Country'].str.lstrip()
elevation.set_index('Country', inplace=True)
elevation = elevation['Average Elevation (meters)'].str.strip()

# %%
elevation = elevation.astype('float')

# %%
warming = pd.read_excel('https://raw.githubusercontent.com/koamahuna/ML_Final_Data/main/Warming_data%20(3).xlsx')

# %%
warming.set_index('Country', inplace=True)
warming = warming['Temperature clean']/58

# %%
index_list = ['Coal Production', 
              'Coal Consumption', 
              'Nuclear Production', 
              'Nuclear Consumption', 
              'Natural Gas Production', 
              'Natural Gas Consumption', 
              'Hydroelectric Production', 
              'Hydroelectric Consumption', 
              'Oil Production', 
              'Oil Consumption', 
              'Solar Production', 
              'Solar Consumption', 
              'Wind Production', 
              'Wind Consumption',
              'Carbon Dioxide Emissions',
              'GDP Growth Rate',
              'Population Growth Rate',
              'Elevation',
              'Annual Warming Rate']

# %%
energy_df = pd.DataFrame([coal_prod, coal_cons, nuke_prod, nuke_cons, natgas_prod, natgas_cons, hydro_prod, hydro_cons, oil_prod, oil_cons, sol_prod, sol_cons, wind_prod, wind_cons, co2, gdp, pop, elevation, warming], index=index_list).replace('?', np.nan).T

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, Canada to Virgin Islands
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Coal Production            46 non-null     object
#  1   Coal Consumption           91 non-null     object
#  2   Nuclear Production         36 non-null     object
#  3   Nuclear Consumption        36 non-null     object
#  4   Natural Gas Production     61 non-null     object
#  5   Natural Gas Consumption    93 non-null     object
#  6   Hydroelectric Production   87 non-null     object
#  7   Hydroelectric Consumption  86 non-null     object
#  8   Oil Production             60 non-null     object
#  9   Oil Consumption            97 non-null     object
#  10  Solar Production           63 non-null     object
#  11  Solar Consumption          63 non-null     object
#  12  Wind Production            78 non-null     object
#  13  Wind Consumption           78 non-null     object
#  14  Carbon Dioxide Emissions   97 non-null     object
#  15  GDP Growth Rate            253 non-null    object
#  16  Population Growth Rate     263 non-null    object
#  17  Elevation                  159 non-null    object
#  18  Annual Warming Rate        237 non-null    object
# dtypes: object(19)
# memory usage: 54.7+ KB

# %%
convert_cols = ['Coal Production', 'Coal Consumption', 'Nuclear Production',
       'Nuclear Consumption', 'Natural Gas Production',
       'Natural Gas Consumption', 'Hydroelectric Production',
       'Hydroelectric Consumption', 'Oil Production', 'Oil Consumption',
       'Solar Production', 'Solar Consumption', 'Wind Production',
       'Wind Consumption', 'Carbon Dioxide Emissions']

for i in convert_cols:
  energy_df[i] = energy_df[i].str.replace(r'%', '').astype('float')

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, Canada to Virgin Islands
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Coal Production            46 non-null     float64
#  1   Coal Consumption           91 non-null     float64
#  2   Nuclear Production         36 non-null     float64
#  3   Nuclear Consumption        36 non-null     float64
#  4   Natural Gas Production     61 non-null     float64
#  5   Natural Gas Consumption    93 non-null     float64
#  6   Hydroelectric Production   87 non-null     float64
#  7   Hydroelectric Consumption  86 non-null     float64
#  8   Oil Production             60 non-null     float64
#  9   Oil Consumption            97 non-null     float64
#  10  Solar Production           63 non-null     float64
#  11  Solar Consumption          63 non-null     float64
#  12  Wind Production            78 non-null     float64
#  13  Wind Consumption           78 non-null     float64
#  14  Carbon Dioxide Emissions   97 non-null     float64
#  15  GDP Growth Rate            253 non-null    object
#  16  Population Growth Rate     263 non-null    object
#  17  Elevation                  159 non-null    object
#  18  Annual Warming Rate        237 non-null    object
# dtypes: float64(15), object(4)
# memory usage: 54.7+ KB

# %%
null_slice = energy_df[energy_df.isnull().sum(axis=1)/18 <= .4]
null_slice.fillna(null_slice.mean(), inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
null_slice['paris_accord'] = ((energy_df['Annual Warming Rate'] >0.03444492943401715).astype(int))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_cols = ['Coal Production', 'Coal Consumption', 'Nuclear Production',
       'Nuclear Consumption', 'Natural Gas Production',
       'Natural Gas Consumption', 'Hydroelectric Production',
       'Hydroelectric Consumption', 'Oil Production', 'Oil Consumption',
       'Solar Production', 'Solar Consumption', 'Wind Production',
       'Wind Consumption', 'Carbon Dioxide Emissions', 'GDP Growth Rate',
       'Population Growth Rate', 'Elevation']

y_cols = 'paris_accord'

# %% [markdown]
# #Data Quality Analysis

# %%
new_data['Country'] = new_data['Country'].map(lambda x:x.strip())

# %%
new_data_slice = new_data.set_index('Country')[['Population', 'Area (sq. mi.)',
       'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
       'Net migration', 'Infant mortality (per 1000 births)',
       'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
       'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
       'Agriculture', 'Industry', 'Service']]

# %%
emissions
# Out:
#        Country Name  Emissions
# 0       Afghanistan       0.28
# 1           Albania       1.80
# 2           Algeria       3.85
# 3            Angola       1.06
# 4          Anguilla       2.10
# ..              ...        ...
# 204         Vietnam       2.20
# 205  Western Sahara       0.39
# 206           Yemen       0.94
# 207          Zambia       0.26
# 208        Zimbabwe       0.72
#
# [209 rows x 2 columns]

# %%
emissions_data = emissions.set_index('Country Name')['Emissions']
emissions_data
# Out:
# Country Name
# Afghanistan       0.28
# Albania           1.80
# Algeria           3.85
# Angola            1.06
# Anguilla          2.10
#                   ...
# Vietnam           2.20
# Western Sahara    0.39
# Yemen             0.94
# Zambia            0.26
# Zimbabwe          0.72
# Name: Emissions, Length: 209, dtype: float64

# %%
final_df = new_data_slice.join(emissions_data, how='inner')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, Afghanistan to Zimbabwe
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Population                          182 non-null    int64
#  1   Area (sq. mi.)                      182 non-null    int64
#  2   Pop. Density (per sq. mi.)          182 non-null    float64
#  3   Coastline (coast/area ratio)        182 non-null    float64
#  4   Net migration                       180 non-null    float64
#  5   Infant mortality (per 1000 births)  180 non-null    float64
#  6   GDP ($ per capita)                  181 non-null    float64
#  7   Literacy (%)                        176 non-null    float64
#  8   Phones (per 1000)                   180 non-null    float64
#  9   Arable (%)                          182 non-null    float64
#  10  Crops (%)                           182 non-null    float64
#  11  Other (%)                           182 non-null    float64
#  12  Climate                             164 non-null    float64
#  13  Birthrate                           180 non-null    float64
#  14  Deathrate                           179 non-null    float64
#  15  Agriculture                         178 non-null    float64
#  16  Industry                            178 non-null    float64
#  17  Service                             179 non-null    float64
#  18  Emissions                           182 non-null    float64
# dtypes: float64(17), int64(2)
# memory usage: 28.4+ KB

# %%
final_df
# Out:
#                 Population  Area (sq. mi.)  ...  Service  Emissions
# Afghanistan       31056997          647500  ...    0.380       0.28
# Albania            3581655           28748  ...    0.579       1.80
# Algeria           32930091         2381740  ...    0.298       3.85
# Angola            12127071         1246700  ...    0.246       1.06
# Anguilla             13477             102  ...    0.780       2.10
# ...                    ...             ...  ...      ...        ...
# Vietnam           84402966          329560  ...    0.381       2.20
# Western Sahara      273008          266000  ...    0.400       0.39
# Yemen             21456188          527970  ...    0.393       0.94
# Zambia            11502010          752614  ...    0.489       0.26
# Zimbabwe          12236805          390580  ...    0.579       0.72
#
# [182 rows x 19 columns]

# %%
final_df.isnull().sum()
# Out:
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          2
# Infant mortality (per 1000 births)     2
# GDP ($ per capita)                     1
# Literacy (%)                           6
# Phones (per 1000)                      2
# Arable (%)                             0
# Crops (%)                              0
# Other (%)                              0
# Climate                               18
# Birthrate                              2
# Deathrate                              3
# Agriculture                            4
# Industry                               4
# Service                                3
# Emissions                              0
# dtype: int64

# %%
final_df.fillna(final_df.median(), inplace=True)
final_df.isnull().sum()
# Out:
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# Emissions                             0
# dtype: int64

# %%
final_df.describe()
# Out:
#          Population  Area (sq. mi.)  ...     Service   Emissions
# count  1.820000e+02    1.820000e+02  ...  182.000000  182.000000
# mean   3.454444e+07    7.198589e+05  ...    0.555451    4.598956
# std    1.309078e+08    1.973128e+06  ...    0.158138    5.470965
# min    7.502000e+03    7.000000e+00  ...    0.062000    0.030000
# 25%    1.491480e+06    2.777000e+04  ...    0.427750    0.847500
# 50%    7.130624e+06    1.307170e+05  ...    0.569000    2.645000
# 75%    2.209171e+07    5.244775e+05  ...    0.670750    6.342500
# max    1.313974e+09    1.707520e+07  ...    0.954000   37.290000
#
# [8 rows x 19 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, Afghanistan to Zimbabwe
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Population                          182 non-null    int64
#  1   Area (sq. mi.)                      182 non-null    int64
#  2   Pop. Density (per sq. mi.)          182 non-null    float64
#  3   Coastline (coast/area ratio)        182 non-null    float64
#  4   Net migration                       182 non-null    float64
#  5   Infant mortality (per 1000 births)  182 non-null    float64
#  6   GDP ($ per capita)                  182 non-null    float64
#  7   Literacy (%)                        182 non-null    float64
#  8   Phones (per 1000)                   182 non-null    float64
#  9   Arable (%)                          182 non-null    float64
#  10  Crops (%)                           182 non-null    float64
#  11  Other (%)                           182 non-null    float64
#  12  Climate                             182 non-null    float64
#  13  Birthrate                           182 non-null    float64
#  14  Deathrate                           182 non-null    float64
#  15  Agriculture                         182 non-null    float64
#  16  Industry                            182 non-null    float64
#  17  Service                             182 non-null    float64
#  18  Emissions                           182 non-null    float64
# dtypes: float64(17), int64(2)
# memory usage: 33.4+ KB

# %% [markdown]
# #Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(energy_df.index, energy_df['Coal Consumption'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Coal Consumption Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Coal Production'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Coal Production Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Nuclear Production'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Nuclear Production Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Nuclear Consumption'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Nuclear Consumption Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Natural Gas Production'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Natural Gas Production Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Natural Gas Consumption'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Natural Gas Consumption Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Hydroelectric Production'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Hydroelectric Production Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Hydroelectric Consumption'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Hydroelectric Consumption Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Oil Production'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Oil Production Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Oil Consumption'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Oil Consumption Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Solar Production'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Solar Production Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Solar Consumption'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Solar Consumption Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Wind Production'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Wind Production Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Wind Consumption'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Wind Consumption Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Carbon Dioxide Emissions'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Carbon Dioxide Emission Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['GDP Growth Rate'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('GDP Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Population Growth Rate'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Population Growth Rates for various countries')
plt.show()

# %%
plt.scatter(energy_df.index, energy_df['Elevation'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Elevation Growth Rates for various countries')
plt.show()

# %% [markdown]
# # Model Implementation and Performance Tuning

# %%
null_slice = energy_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-03c347121e20> in <module>()
# ----> 1 null_slice = energy_df
#
# NameError: name 'energy_df' is not defined

# %%
#Set data for the following models
X = final_df[['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
       'Coastline (coast/area ratio)', 'Net migration',
       'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
       'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
       'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
       'Industry', 'Service']]

y = final_df['Emissions']
y = y > y.median()
y = y.astype('float')

X.ffill(inplace=True)
y.ffill(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
#Net Migration Scatter Plot
plt.scatter(final_df.index, final_df['Net migration'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Net migration')
plt.show()

# %%
#Pop Density Scatter Plot
plt.scatter(final_df.index, final_df['Pop. Density (per sq. mi.)'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Pop. Density (per sq. mi.)')
plt.show()

# %%
#Infant Mortality Scatter Plot
plt.scatter(final_df.index, final_df['Infant mortality (per 1000 births)'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Infant mortality (per 1000 births)')
plt.show()

# %%
#GDP Scatter Plot
plt.scatter(final_df.index, final_df['GDP ($ per capita)'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('GDP ($ per capita)')
plt.show()

# %%
# Literacy (%) Scatter Plot

plt.scatter(final_df.index, final_df['Literacy (%)'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Literacy (%)')
plt.show()

# %%
# Phones (per 1000) Scatter Plot
plt.scatter(final_df.index, final_df['Phones (per 1000)'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Phones (per 1000)')
plt.show()

# %%
# Arable (%) Scatter Plot
plt.scatter(final_df.index, final_df['Arable (%)'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Arable (%)')
plt.show()

# %%
# Crops (%) Scatter Plot
plt.scatter(final_df.index, final_df['Crops (%)'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Crops (%)')
plt.show()

# %%
# Birthrate Scatter Plot
plt.scatter(final_df.index, final_df['Birthrate'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Birthrate')
plt.show()

# %%
# Deathrate Scatter Plot
plt.scatter(final_df.index, final_df['Deathrate'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Deathrate')
plt.show()

# %%
# Agriculture Scatter Plot
plt.scatter(final_df.index, final_df['Agriculture'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Agriculture')
plt.show()

# %%
# Industry Scatter Plot
plt.scatter(final_df.index, final_df['Industry'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Industry')
plt.show()

# %%
# Service Scatter Plot
plt.scatter(final_df.index, final_df['Service'])
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)
plt.title('Service')
plt.show()

# %%
#Top 5 Net Migration
big5 = final_df['Industry'].nlargest(5)

plt.barh(big5.index, big5)
figure = plt.gca()
plt.ylabel('Industrial')
plt.xticks(rotation = 45)
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(True)
plt.title('Top 5 Industrial')
plt.show()

# %%
#Top 5 GDP Per Capita
big5 = final_df['GDP ($ per capita)'].nlargest(5)

plt.bar(big5.index, big5)
figure = plt.gca()
plt.ylabel('GDP ($ per capita)')
plt.xticks(rotation = 45)
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(True)
plt.title('Top 5 GDP Per Capita')
plt.show()

# %%
#Top 5 CO2 Per Capita Emitters
big5 = final_df['Emissions'].nlargest(5)

plt.bar(big5.index, big5)
figure = plt.gca()
plt.ylabel('CO2 Tons Per Capita')
plt.xticks(rotation = 45)
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(True)
plt.title('Top 5 CO2 Per Capita')
plt.show()

# %%
#Adding a correlation plot to study variable relationships
import seaborn as sns

corr = final_df.corr() #calculating the correlations between variables in our dataset
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
)
# although some of the correlations do become positive, none of them are troubling
# Out:
# [Text(0.5, 0, 'Population'),
#  Text(1.5, 0, 'Area (sq. mi.)'),
#  Text(2.5, 0, 'Pop. Density (per sq. mi.)'),
#  Text(3.5, 0, 'Coastline (coast/area ratio)'),
#  Text(4.5, 0, 'Net migration'),
#  Text(5.5, 0, 'Infant mortality (per 1000 births)'),
#  Text(6.5, 0, 'GDP ($ per capita)'),
#  Text(7.5, 0, 'Literacy (%)'),
#  Text(8.5, 0, 'Phones (per 1000)'),
#  Text(9.5, 0, 'Arable (%)'),
#  Text(10.5, 0, 'Crops (%)'),
#  Text(11.5, 0, 'Other (%)'),
#  Text(12.5, 0, 'Climate'),
#  Text(13.5, 0, 'Birthrate'),
#  Text(14.5, 0, 'Deathrate'),
#  Text(15.5, 0, 'Agriculture'),
#  Text(16.5, 0, 'Industry'),
#  Text(17.5, 0, 'Service'),
#  Text(18.5, 0, 'Emissions')]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, Afghanistan to Zimbabwe
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Population                          182 non-null    int64
#  1   Area (sq. mi.)                      182 non-null    int64
#  2   Pop. Density (per sq. mi.)          182 non-null    float64
#  3   Coastline (coast/area ratio)        182 non-null    float64
#  4   Net migration                       182 non-null    float64
#  5   Infant mortality (per 1000 births)  182 non-null    float64
#  6   GDP ($ per capita)                  182 non-null    float64
#  7   Literacy (%)                        182 non-null    float64
#  8   Phones (per 1000)                   182 non-null    float64
#  9   Arable (%)                          182 non-null    float64
#  10  Crops (%)                           182 non-null    float64
#  11  Other (%)                           182 non-null    float64
#  12  Climate                             182 non-null    float64
#  13  Birthrate                           182 non-null    float64
#  14  Deathrate                           182 non-null    float64
#  15  Agriculture                         182 non-null    float64
#  16  Industry                            182 non-null    float64
#  17  Service                             182 non-null    float64
# dtypes: float64(16), int64(2)
# memory usage: 32.0+ KB

# %%
X.describe()
# Out:
#          Population  Area (sq. mi.)  ...    Industry     Service
# count  1.820000e+02    1.820000e+02  ...  182.000000  182.000000
# mean   3.454444e+07    7.198589e+05  ...    0.291665    0.555451
# std    1.309078e+08    1.973128e+06  ...    0.134082    0.158138
# min    7.502000e+03    7.000000e+00  ...    0.032000    0.062000
# 25%    1.491480e+06    2.777000e+04  ...    0.204000    0.427750
# 50%    7.130624e+06    1.307170e+05  ...    0.276000    0.569000
# 75%    2.209171e+07    5.244775e+05  ...    0.342750    0.670750
# max    1.313974e+09    1.707520e+07  ...    0.906000    0.954000
#
# [8 rows x 18 columns]

# %%
final_df.columns
# Out:
# Index(['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
#        'Coastline (coast/area ratio)', 'Net migration',
#        'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
#        'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
#        'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
#        'Industry', 'Service', 'Emissions'],
#       dtype='object')

# %%
X = final_df[['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
       'Coastline (coast/area ratio)', 'Net migration',
       'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
       'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
       'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
       'Industry', 'Service']]

# %%
y = final_df['Emissions']

# %% [markdown]
# ###Individual Model Comparison

# %%
cart_X = X

# %%
cart_y = y > y.mean()
cart_y.astype(float)
# Out:
# Afghanistan       0.0
# Albania           0.0
# Algeria           0.0
# Angola            0.0
# Anguilla          0.0
#                  ...
# Vietnam           0.0
# Western Sahara    0.0
# Yemen             0.0
# Zambia            0.0
# Zimbabwe          0.0
# Name: Emissions, Length: 182, dtype: float64

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

dtree = DecisionTreeClassifier(criterion = 'entropy', max_depth = None, random_state = 99,
                               max_features = None, min_samples_leaf = 25, min_samples_split = 25)
x_train, x_test, y_train, y_test = train_test_split(cart_X,cart_y, random_state = 44)
dtree.fit(x_train, y_train)
y_pred = dtree.predict(x_test)

# %%
import graphviz

dot_data = tree.export_graphviz(dtree, out_file = None, filled = True)
graph = graphviz.Source(dot_data, format = "png") 
graph

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, plot_roc_curve

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average = 'micro')
recall = recall_score(y_test, y_pred, average = 'micro')
f1_score = f1_score(y_test, y_pred, average = 'micro')
cm = confusion_matrix(y_pred, y_test)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1_score)
print(cm)
# Out:
# Accuracy: 0.8478260869565217
# Precision: 0.8478260869565217
# Recall: 0.8478260869565217
# F1 Score: 0.8478260869565218
# [[29  3]
#  [ 4 10]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.88      0.89        33
#         True       0.71      0.77      0.74        13
#
#     accuracy                           0.85        46
#    macro avg       0.81      0.82      0.82        46
# weighted avg       0.85      0.85      0.85        46

# %% [markdown]
# #### Test Model 2: Gradient-Boosted Model Classifier and Regressor (Stu's Model)
# by Kiejstut Bunikiewicz

# %%
gbm_X = X

# %%
gbm_y = cart_y

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %%
X_train,X_test,y_train,y_test = train_test_split(gbm_X,gbm_y,test_size = 0.3, random_state = 44)

# %%
X_train.head()
# Out:
#                    Population  Area (sq. mi.)  ...  Industry  Service
# Equatorial Guinea      540109           28051  ...     0.906    0.062
# Namibia               2044147          825418  ...     0.315    0.588
# Kuwait                2418393           17820  ...     0.479    0.516
# Serbia                9396411           88361  ...     0.255    0.579
# United Kingdom       60609153          244820  ...     0.237    0.758
#
# [5 rows x 18 columns]

# %%
y_train.head()
# Out:
# Equatorial Guinea    False
# Namibia              False
# Kuwait                True
# Serbia                True
# United Kingdom        True
# Name: Emissions, dtype: bool

# %%
y.value_counts() # about 3x 0s per 1s
# Out:
# 0.18    4
# 0.10    3
# 0.28    3
# 4.61    3
# 0.11    2
#        ..
# 0.40    1
# 0.21    1
# 8.34    1
# 4.86    1
# 2.25    1
# Name: Emissions, Length: 162, dtype: int64

# %%
#Gradient Boost (Classifier)
# training the Gradient Boost
results = [] # empty list for appending accuracy results
n_estimator_options = [10, 20, 30, 40, 50] # list for number of estimator options
for est in n_estimator_options:
    model = GradientBoostingClassifier(n_estimators=est, random_state= 101) # model loops through the options for number of estimators hyperparameter
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = np.mean(y_test == y_pred) #accuracy calculation
    results.append(accuracy)
    auc_score = roc_auc_score(y_test, y_pred) #AUC calculation
    print("Accuracy", est, ":", accuracy)
    print("AUC   ", est, ":", auc_score) #printing AUC and Accuracy calculations for the different numbers of estimators

plt.figure(figsize = (8,4))
pd.Series(results, n_estimator_options).plot(color='darkblue', marker = 's')
plt.xlabel("Number of Estimators")
plt.ylabel("Accuracy") # plotting accuracy against number of estimators
plt.title("Gradient Boosting Classifier")
plt.show()
# Out:
# Accuracy 10 : 0.8909090909090909
# AUC    10 : 0.8475975975975977
# Accuracy 20 : 0.8727272727272727
# AUC    20 : 0.8340840840840841
# Accuracy 30 : 0.8727272727272727
# AUC    30 : 0.8340840840840841
# Accuracy 40 : 0.8545454545454545
# AUC    40 : 0.8063063063063063
# Accuracy 50 : 0.8545454545454545
# AUC    50 : 0.8063063063063063

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.85      0.95      0.90        37
#         True       0.86      0.67      0.75        18
#
#     accuracy                           0.85        55
#    macro avg       0.86      0.81      0.82        55
# weighted avg       0.85      0.85      0.85        55

# %%
#Gradient Boost (Regression)   #Getting a r^2 of about 50% as maximum
# training the Gradient Boost
results = [] # empty list for appending accuracy results
n_estimator_options = [20, 40, 60, 80, 100] # list for number of estimator options
for est in n_estimator_options:
    model = GradientBoostingRegressor(n_estimators=est, learning_rate= .1,criterion= 'mse', random_state= 101) # model loops through the options for number of estimators hyperparameter
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    rsq = model.score(X_test, y_test) #R^2 calculation / Accuracy calculation
    results.append(rsq)
    print("R^2", est, ":", rsq)

plt.figure(figsize = (8,4))
pd.Series(results, n_estimator_options).plot(color='darkblue', marker = 's')
plt.xlabel("Number of Estimators")
plt.ylabel("R^2 or Accuracy ") # plotting accuracy against number of estimators
plt.title("Gradient Boosting Regression")
# Out:
# R^2 20 : 0.5305257368436754
# R^2 40 : 0.49378474030989444
# R^2 60 : 0.48250590658492154
# R^2 80 : 0.47637713976575113
# R^2 100 : 0.47592051435107763
# Text(0.5, 1.0, 'Gradient Boosting Regression')

# %%
# Re-trying but with a standard Scaler Code Source : https://vitalflux.com/gradient-boosting-regression-python-examples/
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

# %%
# Standardize the dataset
#
sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.transform(X_test)

# %%
# Hyperparameters for GradientBoostingRegressor
#
gbr_params = {'n_estimators': 25,
          'max_depth': 3,
          'min_samples_split': 5,
          'learning_rate': 0.1,
          'loss': 'ls'}

# %%
# Create an instance of gradient boosting regressor
#
gbr = GradientBoostingRegressor(**gbr_params)

# %%
# Fit the model
#
gbr.fit(X_train_std, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=5,
#                           min_weight_fraction_leaf=0.0, n_estimators=25,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# Print Coefficient of determination R^2
#
print("Model Accuracy: %.3f" % gbr.score(X_test_std, y_test))  #Model accuracy about 50%
#
# Create the mean squared error
#
mse = mean_squared_error(y_test, gbr.predict(X_test_std))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# Model Accuracy: 0.535
# The mean squared error (MSE) on test set: 0.1024

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance
#
# Get Feature importance data using feature_importances_ attribute
#
feature_importance = gbr.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(X.columns)[sorted_idx])
plt.title('Feature Importance (MDI)')
result = permutation_importance(gbr, X_test_std, y_test, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()
fig.tight_layout()
plt.show()

# %%
test_score = np.zeros((gbr_params['n_estimators'],), dtype=np.float64)
for i, y_pred in enumerate(gbr.staged_predict(X_test_std)):
    test_score[i] = gbr.loss_(y_test, y_pred)
 
fig = plt.figure(figsize=(8, 8))
plt.subplot(1, 1, 1)
plt.title('Deviance')
plt.plot(np.arange(gbr_params['n_estimators']) + 1, gbr.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(gbr_params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')
fig.tight_layout()
plt.show()

# %% [markdown]
# #### Test Model 3: Neural Networks (Koa's Model)

# %%
nn_X = X

# %%
len(nn_X.columns)
# Out:
# 18

# %%
nn_y = y

# %%
nn_y = nn_y > nn_y.mean()

# %%
nn_y.astype(float)
# Out:
# Afghanistan       0.0
# Albania           0.0
# Algeria           0.0
# Angola            0.0
# Anguilla          0.0
#                  ...
# Vietnam           0.0
# Western Sahara    0.0
# Yemen             0.0
# Zambia            0.0
# Zimbabwe          0.0
# Name: Emissions, Length: 182, dtype: float64

# %%
#Dependencies
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(nn_X,nn_y,test_size = 0.2, random_state = 44)

# %%
model = keras.Sequential([
  keras.layers.Dense(18, input_dim=18, kernel_initializer='normal', activation='sigmoid'),
  keras.layers.Dense(12, kernel_initializer='normal', activation='sigmoid'),
  keras.layers.Dense(6, kernel_initializer='normal', activation='sigmoid'),
  keras.layers.Dense(1, kernel_initializer='normal', activation='sigmoid'),
])

# %%
model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['acc'])

# %%
history = model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 3ms/step - loss: 0.6994 - acc: 0.4221
# Epoch 2/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6968 - acc: 0.4429
# Epoch 3/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6980 - acc: 0.3891
# Epoch 4/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6971 - acc: 0.3674
# Epoch 5/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6944 - acc: 0.4247
# Epoch 6/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6936 - acc: 0.4247
# Epoch 7/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6927 - acc: 0.6131
# Epoch 8/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6919 - acc: 0.5731
# Epoch 9/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6917 - acc: 0.5588
# Epoch 10/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6912 - acc: 0.5562
# Epoch 11/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6877 - acc: 0.6209
# Epoch 12/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6841 - acc: 0.6669
# Epoch 13/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6904 - acc: 0.5501
# Epoch 14/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6884 - acc: 0.5744
# Epoch 15/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6869 - acc: 0.5862
# Epoch 16/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6851 - acc: 0.6000
# Epoch 17/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6831 - acc: 0.6131
# Epoch 18/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6828 - acc: 0.6087
# Epoch 19/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6819 - acc: 0.6113
# Epoch 20/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6827 - acc: 0.6009
# Epoch 21/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6795 - acc: 0.6213
# Epoch 22/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6809 - acc: 0.6079
# Epoch 23/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6766 - acc: 0.6326
# Epoch 24/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6844 - acc: 0.5770
# Epoch 25/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6797 - acc: 0.6057
# Epoch 26/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6763 - acc: 0.6239
# Epoch 27/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6853 - acc: 0.5679
# Epoch 28/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6851 - acc: 0.5684
# Epoch 29/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6738 - acc: 0.6313
# Epoch 30/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6821 - acc: 0.5836
# Epoch 31/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6864 - acc: 0.5592
# Epoch 32/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6778 - acc: 0.6035
# Epoch 33/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6859 - acc: 0.5614
# Epoch 34/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6796 - acc: 0.5914
# Epoch 35/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6837 - acc: 0.5714
# Epoch 36/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6872 - acc: 0.5549
# Epoch 37/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6780 - acc: 0.5961
# Epoch 38/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6779 - acc: 0.5957
# Epoch 39/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6847 - acc: 0.5653
# Epoch 40/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6841 - acc: 0.5679
# Epoch 41/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6857 - acc: 0.5610
# Epoch 42/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6749 - acc: 0.6053
# Epoch 43/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6788 - acc: 0.5888
# Epoch 44/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6838 - acc: 0.5688
# Epoch 45/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6813 - acc: 0.5783
# Epoch 46/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6810 - acc: 0.5792
# Epoch 47/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6743 - acc: 0.6044
# Epoch 48/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6786 - acc: 0.5879
# Epoch 49/50
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6669 - acc: 0.6317
# Epoch 50/50
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6794 - acc: 0.5844

# %%
y_train.value_counts()
# Out:
# False    77
# True     50
# Name: Emissions, dtype: int64

# %%
prediction = model.predict(X_test)

# %%
model.weights[1]
# Out:
# <tf.Variable 'dense_16/bias:0' shape=(18,) dtype=float32, numpy=
# array([ 7.3584633e-05, -3.5178836e-03, -1.0050511e-02, -2.3680076e-03,
#        -8.7465420e-03,  8.0078812e-03,  1.4320439e-02,  8.7129101e-03,
#         8.0981171e-03,  3.7921900e-03, -7.6886662e-03, -3.2236988e-03,
#        -1.8598689e-02, -6.9199032e-03, -1.5367570e-02, -6.7659183e-03,
#        -6.5541384e-03,  1.1160959e-04], dtype=float32)>

# %%
model.layers[-1].get_weights()
# Out:
# [array([[ 0.08601062],
#         [-0.09687935],
#         [-0.00644201],
#         [-0.02335867],
#         [-0.0381094 ],
#         [-0.0110842 ]], dtype=float32), array([0.00609848], dtype=float32)]

# %%
accuracy_scores = history.history['acc']

# %%
sum(accuracy_scores)/len(accuracy_scores)
# Out:
# 0.5717241567373276

# %%
nn_X = final_df[['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
       'Coastline (coast/area ratio)', 'Net migration',
       'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
       'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
       'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
       'Industry', 'Service']]

# %%
nn_y = final_df['Emissions']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(nn_X,nn_y,test_size = 0.2, random_state = 44)

# %%
y_train.max()
# Out:
# 37.29

# %%
model = keras.Sequential([
  keras.layers.Dense(18, input_dim=18, kernel_initializer='normal', activation='linear'),
  keras.layers.Dense(12, kernel_initializer='normal', activation='linear'),
  keras.layers.Dense(6, kernel_initializer='normal', activation='linear'),
  keras.layers.Dense(1, kernel_initializer='normal', activation='linear'),
])

# %%
model.compile(loss='mean_squared_error', optimizer='Adam', metrics=["mean_squared_error"])

# %%
y_train.min()
# Out:
# 0.03

# %%
history = model.fit(X_train, y_train, epochs=50)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 59978973.3333 - mean_squared_error: 59978973.3333
# Epoch 2/50
# 5/5 [==============================] - 0s 3ms/step - loss: 231386526.6667 - mean_squared_error: 231386526.6667
# Epoch 3/50
# 5/5 [==============================] - 0s 3ms/step - loss: 7648743.3281 - mean_squared_error: 7648743.3281
# Epoch 4/50
# 5/5 [==============================] - 0s 3ms/step - loss: 25036810.1667 - mean_squared_error: 25036810.1667
# Epoch 5/50
# 5/5 [==============================] - 0s 4ms/step - loss: 6464755.1250 - mean_squared_error: 6464755.1250
# Epoch 6/50
# 5/5 [==============================] - 0s 4ms/step - loss: 1751172.3333 - mean_squared_error: 1751172.3333
# Epoch 7/50
# 5/5 [==============================] - 0s 3ms/step - loss: 14320628.8438 - mean_squared_error: 14320628.8438
# Epoch 8/50
# 5/5 [==============================] - 0s 3ms/step - loss: 4696196.1042 - mean_squared_error: 4696196.1042
# Epoch 9/50
# 5/5 [==============================] - 0s 3ms/step - loss: 712532.8438 - mean_squared_error: 712532.8438
# Epoch 10/50
# 5/5 [==============================] - 0s 3ms/step - loss: 1650202.7806 - mean_squared_error: 1650202.7806
# Epoch 11/50
# 5/5 [==============================] - 0s 3ms/step - loss: 4305281.0417 - mean_squared_error: 4305281.0417
# Epoch 12/50
# 5/5 [==============================] - 0s 4ms/step - loss: 30019.0495 - mean_squared_error: 30019.0495
# Epoch 13/50
# 5/5 [==============================] - 0s 3ms/step - loss: 236339.3529 - mean_squared_error: 236339.3529
# Epoch 14/50
# 5/5 [==============================] - 0s 4ms/step - loss: 368628.6953 - mean_squared_error: 368628.6953
# Epoch 15/50
# 5/5 [==============================] - 0s 3ms/step - loss: 16780.6529 - mean_squared_error: 16780.6529
# Epoch 16/50
# 5/5 [==============================] - 0s 3ms/step - loss: 90406.2513 - mean_squared_error: 90406.2513
# Epoch 17/50
# 5/5 [==============================] - 0s 4ms/step - loss: 8748.4674 - mean_squared_error: 8748.4674
# Epoch 18/50
# 5/5 [==============================] - 0s 3ms/step - loss: 6693.0519 - mean_squared_error: 6693.0519
# Epoch 19/50
# 5/5 [==============================] - 0s 4ms/step - loss: 4487.3883 - mean_squared_error: 4487.3883
# Epoch 20/50
# 5/5 [==============================] - 0s 3ms/step - loss: 399.5785 - mean_squared_error: 399.5785
# Epoch 21/50
# 5/5 [==============================] - 0s 3ms/step - loss: 3189.6706 - mean_squared_error: 3189.6706
# Epoch 22/50
# 5/5 [==============================] - 0s 3ms/step - loss: 668.4887 - mean_squared_error: 668.4887
# Epoch 23/50
# 5/5 [==============================] - 0s 3ms/step - loss: 307.5618 - mean_squared_error: 307.5618
# Epoch 24/50
# 5/5 [==============================] - 0s 3ms/step - loss: 356.1712 - mean_squared_error: 356.1712
# Epoch 25/50
# 5/5 [==============================] - 0s 3ms/step - loss: 667.7220 - mean_squared_error: 667.7220
# Epoch 26/50
# 5/5 [==============================] - 0s 5ms/step - loss: 504.1401 - mean_squared_error: 504.1401
# Epoch 27/50
# 5/5 [==============================] - 0s 4ms/step - loss: 80.3489 - mean_squared_error: 80.3489
# Epoch 28/50
# 5/5 [==============================] - 0s 3ms/step - loss: 287.3352 - mean_squared_error: 287.3352
# Epoch 29/50
# 5/5 [==============================] - 0s 4ms/step - loss: 63.1259 - mean_squared_error: 63.1259
# Epoch 30/50
# 5/5 [==============================] - 0s 4ms/step - loss: 64.0668 - mean_squared_error: 64.0668
# Epoch 31/50
# 5/5 [==============================] - 0s 3ms/step - loss: 77.5511 - mean_squared_error: 77.5511
# Epoch 32/50
# 5/5 [==============================] - 0s 3ms/step - loss: 81.8544 - mean_squared_error: 81.8544
# Epoch 33/50
# 5/5 [==============================] - 0s 3ms/step - loss: 53.0641 - mean_squared_error: 53.0641
# Epoch 34/50
# 5/5 [==============================] - 0s 4ms/step - loss: 64.4962 - mean_squared_error: 64.4962
# Epoch 35/50
# 5/5 [==============================] - 0s 3ms/step - loss: 54.8201 - mean_squared_error: 54.8201
# Epoch 36/50
# 5/5 [==============================] - 0s 4ms/step - loss: 65.1544 - mean_squared_error: 65.1544
# Epoch 37/50
# 5/5 [==============================] - 0s 4ms/step - loss: 46.9084 - mean_squared_error: 46.9084
# Epoch 38/50
# 5/5 [==============================] - 0s 4ms/step - loss: 47.8356 - mean_squared_error: 47.8356
# Epoch 39/50
# 5/5 [==============================] - 0s 3ms/step - loss: 46.0245 - mean_squared_error: 46.0245
# Epoch 40/50
# 5/5 [==============================] - 0s 3ms/step - loss: 48.9652 - mean_squared_error: 48.9652
# Epoch 41/50
# 5/5 [==============================] - 0s 4ms/step - loss: 46.1480 - mean_squared_error: 46.1480
# Epoch 42/50
# 5/5 [==============================] - 0s 4ms/step - loss: 39.2505 - mean_squared_error: 39.2505
# Epoch 43/50
# 5/5 [==============================] - 0s 3ms/step - loss: 32.4660 - mean_squared_error: 32.4660
# Epoch 44/50
# 5/5 [==============================] - 0s 3ms/step - loss: 41.7096 - mean_squared_error: 41.7096
# Epoch 45/50
# 5/5 [==============================] - 0s 3ms/step - loss: 33.8533 - mean_squared_error: 33.8533
# Epoch 46/50
# 5/5 [==============================] - 0s 3ms/step - loss: 42.4135 - mean_squared_error: 42.4135
# Epoch 47/50
# 5/5 [==============================] - 0s 3ms/step - loss: 24.7635 - mean_squared_error: 24.7635
# Epoch 48/50
# 5/5 [==============================] - 0s 4ms/step - loss: 34.8029 - mean_squared_error: 34.8029
# Epoch 49/50
# 5/5 [==============================] - 0s 3ms/step - loss: 31.7747 - mean_squared_error: 31.7747
# Epoch 50/50
# 5/5 [==============================] - 0s 3ms/step - loss: 29.9348 - mean_squared_error: 29.9348

# %%
prediction
# Out:
# array([[0.4317785 ],
#        [0.4317785 ],
#        [0.43178463],
#        [0.43178463],
#        [0.4317785 ],
#        [0.43178463],
#        [0.43178463],
#        [0.4317785 ],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.4317785 ],
#        [0.43178463],
#        [0.43178463],
#        [0.4317785 ],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.4317785 ],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.4317785 ],
#        [0.4317785 ],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.43174314],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463],
#        [0.43178463]], dtype=float32)

# %%
y_test
# Out:
# Angola                 1.06
# Peru                   1.87
# El Salvador            1.08
# Tonga                  2.49
# Mali                   0.09
# Austria                8.43
# Kyrgyzstan             1.14
# Kazakhstan            13.01
# Costa Rica             1.70
# Guadeloupe             6.20
# Egypt                  2.32
# Turkmenistan          14.00
# Tajikistan             0.70
# Georgia                2.14
# Zambia                 0.26
# Dominican Republic     2.26
# United States         15.52
# Dominica               2.61
# Chile                  4.46
# Cameroon               0.40
# Ecuador                2.43
# Zimbabwe               0.72
# New Caledonia          8.53
# Algeria                3.85
# Bangladesh             0.47
# Benin                  0.60
# Kiribati               0.47
# Senegal                0.55
# Saint Helena           2.20
# Guinea-Bissau          0.18
# Spain                  5.40
# Ireland                8.32
# Mauritania             0.62
# Mozambique             0.21
# Honduras               1.01
# China                  7.38
# Burundi                0.10
# Name: Emissions, dtype: float64

# %%
plt.plot(y_test)
plt.plot(prediction)

# %%
history.history
# Out:
# {'loss': [56.80329895019531,
#   56.73826217651367,
#   56.67261505126953,
#   56.60051727294922,
#   56.519073486328125,
#   56.4283561706543,
#   56.33149337768555,
#   56.20900344848633,
#   56.06523132324219,
#   55.895442962646484,
#   55.70201110839844,
#   55.47098922729492,
#   55.194580078125,
#   54.87234878540039,
#   54.48836135864258,
#   54.060264587402344,
#   53.57919692993164,
#   52.968963623046875,
#   52.3306884765625,
#   51.620819091796875,
#   50.80253982543945,
#   49.911922454833984,
#   48.986080169677734,
#   47.973052978515625,
#   46.867530822753906,
#   45.740966796875,
#   44.553794860839844,
#   43.29840850830078,
#   42.14661407470703,
#   40.75782775878906,
#   39.81333541870117,
#   38.5407829284668,
#   37.59284973144531,
#   36.70083999633789,
#   35.81237030029297,
#   35.08931350708008,
#   34.55477523803711,
#   33.98009490966797,
#   33.529205322265625,
#   33.27273178100586,
#   32.96648025512695,
#   32.82122802734375,
#   32.71959686279297,
#   32.63005447387695,
#   32.60923767089844,
#   32.59450912475586,
#   32.5564079284668,
#   32.59604263305664,
#   32.556365966796875,
#   32.53207015991211],
#  'mean_squared_error': [56.80329895019531,
#   56.73826217651367,
#   56.67261505126953,
#   56.60051727294922,
#   56.519073486328125,
#   56.4283561706543,
#   56.33149337768555,
#   56.20900344848633,
#   56.06523132324219,
#   55.895442962646484,
#   55.70201110839844,
#   55.47098922729492,
#   55.194580078125,
#   54.87234878540039,
#   54.48836135864258,
#   54.060264587402344,
#   53.57919692993164,
#   52.968963623046875,
#   52.3306884765625,
#   51.620819091796875,
#   50.80253982543945,
#   49.911922454833984,
#   48.986080169677734,
#   47.973052978515625,
#   46.867530822753906,
#   45.740966796875,
#   44.553794860839844,
#   43.29840850830078,
#   42.14661407470703,
#   40.75782775878906,
#   39.81333541870117,
#   38.5407829284668,
#   37.59284973144531,
#   36.70083999633789,
#   35.81237030029297,
#   35.08931350708008,
#   34.55477523803711,
#   33.98009490966797,
#   33.529205322265625,
#   33.27273178100586,
#   32.96648025512695,
#   32.82122802734375,
#   32.71959686279297,
#   32.63005447387695,
#   32.60923767089844,
#   32.59450912475586,
#   32.5564079284668,
#   32.59604263305664,
#   32.556365966796875,
#   32.53207015991211]}

# %% [markdown]
# ###Test Model 1: CART (Jerry's Model)

# %%
d_X = cart_X

# %%
d_y = cart_y

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(d_X,d_y,test_size = 0.2, random_state = 44)

# %%
from sklearn.inspection import permutation_importance

# %%
model = DecisionTreeClassifier(criterion='entropy',random_state=99, max_depth=4)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=99, splitter='best')

# %%
model.score(X_test, y_test)
# Out:
# 0.918918918918919

# %%
from sklearn.metrics import classification_report

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.96      0.95        28
#         True       0.88      0.78      0.82         9
#
#     accuracy                           0.92        37
#    macro avg       0.90      0.87      0.89        37
# weighted avg       0.92      0.92      0.92        37

# %%
results = permutation_importance(model, d_X, d_y, scoring='accuracy')

# %%
importance = results.importances_mean
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.xticks(range(0,18))
plt.show()
# Out:
# Feature: 0, Score: 0.05934
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.00549
# Feature: 3, Score: 0.00000
# Feature: 4, Score: 0.08242
# Feature: 5, Score: 0.00330
# Feature: 6, Score: 0.00000
# Feature: 7, Score: 0.00659
# Feature: 8, Score: 0.24945
# Feature: 9, Score: 0.00000
# Feature: 10, Score: 0.03187
# Feature: 11, Score: 0.02967
# Feature: 12, Score: 0.00000
# Feature: 13, Score: 0.00000
# Feature: 14, Score: 0.00000
# Feature: 15, Score: 0.03297
# Feature: 16, Score: 0.00000
# Feature: 17, Score: 0.01868

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()

export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %% [markdown]
# ### Top Model : GradientBoostClassifier & Hyperparameter Tuning

# %%
X
# Out:
#                 Population  Area (sq. mi.)  ...  Industry  Service
# Afghanistan       31056997          647500  ...     0.240    0.380
# Albania            3581655           28748  ...     0.188    0.579
# Algeria           32930091         2381740  ...     0.600    0.298
# Angola            12127071         1246700  ...     0.658    0.246
# Anguilla             13477             102  ...     0.180    0.780
# ...                    ...             ...  ...       ...      ...
# Vietnam           84402966          329560  ...     0.410    0.381
# Western Sahara      273008          266000  ...     0.276    0.400
# Yemen             21456188          527970  ...     0.472    0.393
# Zambia            11502010          752614  ...     0.290    0.489
# Zimbabwe          12236805          390580  ...     0.243    0.579
#
# [182 rows x 18 columns]

# %%
y = y > y.mean()

# %%
y.astype(float)
# Out:
# Afghanistan       0.0
# Albania           0.0
# Algeria           0.0
# Angola            0.0
# Anguilla          0.0
#                  ...
# Vietnam           0.0
# Western Sahara    0.0
# Yemen             0.0
# Zambia            0.0
# Zimbabwe          0.0
# Name: Emissions, Length: 182, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state =44)

# %%
top_model = GradientBoostingClassifier(n_estimators=est, random_state= 101) # model loops through the options for number of estimators hyperparameter
top_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=101, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# define a parameter grid of the tuning parameters
param_grid = {}
param_grid['n_estimators'] = [5, 10, 15, 20, 25, 30]
param_grid['criterion'] = ['friedman_mse', 'mse', 'mae']
param_grid['learning_rate'] = [0.1, 0.15, 0.20]
param_grid['loss'] = ['deviance','exponential']
param_grid['max_depth'] = [2,3,4,5]
param_grid['min_samples_leaf'] = [2, 3, 4]

# %%
# run the grid search and examine the scores
#grid = GridSearchCV(top_model, param_grid, cv=5, scoring='roc_auc', verbose = 2)
#grid.fit(X, y)
#results = pd.DataFrame(grid.cv_results_)
#results[['mean_test_score', 'std_test_score', 'params']]

# %%
# examine the score and parameters of the best model

#print(grid.best_score_)   #Printing auc of the best model
#print(grid.best_params_)

# %%
#Running Hyperparameter Tuned Gradient Boosted Classifier
top_model = GradientBoostingClassifier(criterion= 'friedman_mse', learning_rate=0.2,loss='exponential', max_depth= 2, min_samples_leaf= 2, n_estimators= 20, random_state= 101) # model loops through the options for number of estimators hyperparameter
top_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.2, loss='exponential', max_depth=2,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=2, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=20,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=101, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred)) #Classification report of our final model
# Out:
#               precision    recall  f1-score   support
#
#        False       0.95      0.97      0.96        37
#         True       0.94      0.89      0.91        18
#
#     accuracy                           0.95        55
#    macro avg       0.94      0.93      0.94        55
# weighted avg       0.95      0.95      0.95        55

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([False, False, False, False, False,  True, False,  True,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False, False, False,  True,
#        False,  True,  True, False, False,  True,  True, False, False,
#        False,  True,  True,  True, False, False, False, False,  True,
#         True])

# %%
feat_imp = top_model.feature_importances_

# %%
feature_names = ['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
       'Coastline (coast/area ratio)', 'Net migration',
       'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
       'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
       'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
       'Industry', 'Service']

# %%
feat_imp = pd.Series(top_model.feature_importances_, feature_names).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Importance of Features')
